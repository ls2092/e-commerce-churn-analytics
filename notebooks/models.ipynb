# %% [markdown]
# ### Logistic Regression Model
# #### drop rceency days and customer unique id to prevent data leakage

# %%
import pandas as pd
from sklearn.model_selection import train_test_Split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('C:\Users\user\Desktop\e-commerce-churn-analytics\data\rfm_features1.csv')
# Feature and Target Variables
X = df[['frequency', 'total_spent']]
y = df['churned']
